# %%
from pycparser import c_parser

# %%
text = r"""
    typedef int Node, Hash;
    void HashPrint(Hash* hash, void (*PrintFunc)(char*, char*))
    {
        unsigned int i;
        if (hash == NULL || hash->heads == NULL)
            return;
        for (i = 0; i < hash->table_size; ++i)
        {
            Node* temp = hash->heads[i];
            while (temp != NULL)
            {
                PrintFunc(temp->entry->key, temp->entry->value);
                temp = temp->next;
            }
        }
    }
"""

# %%
parser = c_parser.CParser()
ast = parser.parse(text, filename='<none>')

# %%
ast.show(showcoord=True)
# Out:
# FileAST:  (at None)
#   Typedef: Node, [], ['typedef'] (at <none>:2:17)
#     TypeDecl: Node, [], None (at <none>:2:17)
#       IdentifierType: ['int'] (at <none>:2:13)
#   Typedef: Hash, [], ['typedef'] (at <none>:2:23)
#     TypeDecl: Hash, [], None (at <none>:2:23)
#       IdentifierType: ['int'] (at <none>:2:13)
#   FuncDef:  (at <none>:3:10)
#     Decl: HashPrint, [], [], [], [] (at <none>:3:10)
#       FuncDecl:  (at <none>:3:10)
#         ParamList:  (at <none>:3:24)
#           Decl: hash, [], [], [], [] (at <none>:3:24)
#             PtrDecl: [] (at <none>:3:24)
#               TypeDecl: hash, [], None (at <none>:3:26)
#                 IdentifierType: ['Hash'] (at <none>:3:20)
#           Decl: PrintFunc, [], [], [], [] (at <none>:3:38)
#             PtrDecl: [] (at <none>:3:38)
#               FuncDecl:  (at <none>:3:38)
#                 ParamList:  (at <none>:0:1)
#                   Typename: None, [], None (at <none>:0:1)
#                     PtrDecl: [] (at <none>:3:54)
#                       TypeDecl: None, [], None (at None)
#                         IdentifierType: ['char'] (at <none>:3:50)
#                   Typename: None, [], None (at <none>:0:1)
#                     PtrDecl: [] (at <none>:3:61)
#                       TypeDecl: None, [], None (at None)
#                         IdentifierType: ['char'] (at <none>:3:57)
#                 TypeDecl: PrintFunc, [], None (at <none>:3:39)
#                   IdentifierType: ['void'] (at <none>:3:32)
#         TypeDecl: HashPrint, [], None (at <none>:3:10)
#           IdentifierType: ['void'] (at <none>:3:5)
#     Compound:  (at <none>:4:1)
#       Decl: i, [], [], [], [] (at <none>:5:22)
#         TypeDecl: i, [], None (at <none>:5:22)
#           IdentifierType: ['unsigned', 'int'] (at <none>:5:9)
#       If:  (at <none>:6:9)
#         BinaryOp: || (at <none>:6:13)
#           BinaryOp: == (at <none>:6:13)
#             ID: hash (at <none>:6:13)
#             ID: NULL (at <none>:6:21)
#           BinaryOp: == (at <none>:6:29)
#             StructRef: -> (at <none>:6:29)
#               ID: hash (at <none>:6:29)
#               ID: heads (at <none>:6:35)
#             ID: NULL (at <none>:6:44)
#         Return:  (at <none>:7:13)
#       For:  (at <none>:8:9)
#         Assignment: = (at <none>:8:14)
#           ID: i (at <none>:8:14)
#           Constant: int, 0 (at <none>:8:18)
#         BinaryOp: < (at <none>:8:21)
#           ID: i (at <none>:8:21)
#           StructRef: -> (at <none>:8:25)
#             ID: hash (at <none>:8:25)
#             ID: table_size (at <none>:8:31)
#         UnaryOp: ++ (at <none>:8:45)
#           ID: i (at <none>:8:45)
#         Compound:  (at <none>:9:1)
#           Decl: temp, [], [], [], [] (at <none>:10:17)
#             PtrDecl: [] (at <none>:10:17)
#               TypeDecl: temp, [], None (at <none>:10:19)
#                 IdentifierType: ['Node'] (at <none>:10:13)
#             ArrayRef:  (at <none>:10:26)
#               StructRef: -> (at <none>:10:26)
#                 ID: hash (at <none>:10:26)
#                 ID: heads (at <none>:10:32)
#               ID: i (at <none>:10:38)
#           While:  (at <none>:11:13)
#             BinaryOp: != (at <none>:11:20)
#               ID: temp (at <none>:11:20)
#               ID: NULL (at <none>:11:28)
#             Compound:  (at <none>:12:1)
#               FuncCall:  (at <none>:13:17)
#                 ID: PrintFunc (at <none>:13:17)
#                 ExprList:  (at <none>:13:27)
#                   StructRef: -> (at <none>:13:27)
#                     StructRef: -> (at <none>:13:27)
#                       ID: temp (at <none>:13:27)
#                       ID: entry (at <none>:13:33)
#                     ID: key (at <none>:13:40)
#                   StructRef: -> (at <none>:13:45)
#                     StructRef: -> (at <none>:13:45)
#                       ID: temp (at <none>:13:45)
#                       ID: entry (at <none>:13:51)
#                     ID: value (at <none>:13:58)
#               Assignment: = (at <none>:14:17)
#                 ID: temp (at <none>:14:17)
#                 StructRef: -> (at <none>:14:24)
#                   ID: temp (at <none>:14:24)
#                   ID: next (at <none>:14:30)

# %%
ast.ext[2].show()
# Out:
# FuncDef:
#   Decl: HashPrint, [], [], [], []
#     FuncDecl:
#       ParamList:
#         Decl: hash, [], [], [], []
#           PtrDecl: []
#             TypeDecl: hash, [], None
#               IdentifierType: ['Hash']
#         Decl: PrintFunc, [], [], [], []
#           PtrDecl: []
#             FuncDecl:
#               ParamList:
#                 Typename: None, [], None
#                   PtrDecl: []
#                     TypeDecl: None, [], None
#                       IdentifierType: ['char']
#                 Typename: None, [], None
#                   PtrDecl: []
#                     TypeDecl: None, [], None
#                       IdentifierType: ['char']
#               TypeDecl: PrintFunc, [], None
#                 IdentifierType: ['void']
#       TypeDecl: HashPrint, [], None
#         IdentifierType: ['void']
#   Compound:
#     Decl: i, [], [], [], []
#       TypeDecl: i, [], None
#         IdentifierType: ['unsigned', 'int']
#     If:
#       BinaryOp: ||
#         BinaryOp: ==
#           ID: hash
#           ID: NULL
#         BinaryOp: ==
#           StructRef: ->
#             ID: hash
#             ID: heads
#           ID: NULL
#       Return:
#     For:
#       Assignment: =
#         ID: i
#         Constant: int, 0
#       BinaryOp: <
#         ID: i
#         StructRef: ->
#           ID: hash
#           ID: table_size
#       UnaryOp: ++
#         ID: i
#       Compound:
#         Decl: temp, [], [], [], []
#           PtrDecl: []
#             TypeDecl: temp, [], None
#               IdentifierType: ['Node']
#           ArrayRef:
#             StructRef: ->
#               ID: hash
#               ID: heads
#             ID: i
#         While:
#           BinaryOp: !=
#             ID: temp
#             ID: NULL
#           Compound:
#             FuncCall:
#               ID: PrintFunc
#               ExprList:
#                 StructRef: ->
#                   StructRef: ->
#                     ID: temp
#                     ID: entry
#                   ID: key
#                 StructRef: ->
#                   StructRef: ->
#                     ID: temp
#                     ID: entry
#                   ID: value
#             Assignment: =
#               ID: temp
#               StructRef: ->
#                 ID: temp
#                 ID: next

# %%
function_decl = ast.ext[2].decl

# %%
function_decl.type.show()
# Out:
# FuncDecl:
#   ParamList:
#     Decl: hash, [], [], [], []
#       PtrDecl: []
#         TypeDecl: hash, [], None
#           IdentifierType: ['Hash']
#     Decl: PrintFunc, [], [], [], []
#       PtrDecl: []
#         FuncDecl:
#           ParamList:
#             Typename: None, [], None
#               PtrDecl: []
#                 TypeDecl: None, [], None
#                   IdentifierType: ['char']
#             Typename: None, [], None
#               PtrDecl: []
#                 TypeDecl: None, [], None
#                   IdentifierType: ['char']
#           TypeDecl: PrintFunc, [], None
#             IdentifierType: ['void']
#   TypeDecl: HashPrint, [], None
#     IdentifierType: ['void']

# %%
function_decl.type.args.show()
# Out:
# ParamList:
#   Decl: hash, [], [], [], []
#     PtrDecl: []
#       TypeDecl: hash, [], None
#         IdentifierType: ['Hash']
#   Decl: PrintFunc, [], [], [], []
#     PtrDecl: []
#       FuncDecl:
#         ParamList:
#           Typename: None, [], None
#             PtrDecl: []
#               TypeDecl: None, [], None
#                 IdentifierType: ['char']
#           Typename: None, [], None
#             PtrDecl: []
#               TypeDecl: None, [], None
#                 IdentifierType: ['char']
#         TypeDecl: PrintFunc, [], None
#           IdentifierType: ['void']

# %%
for param_decl in function_decl.type.args.params:
    print('Arg name: %s' % param_decl.name)
    print('Type:')
    param_decl.type.show(offset=6)
# Out:
# Arg name: hash
# Type:
#       PtrDecl: []
#         TypeDecl: hash, [], None
#           IdentifierType: ['Hash']
# Arg name: PrintFunc
# Type:
#       PtrDecl: []
#         FuncDecl:
#           ParamList:
#             Typename: None, [], None
#               PtrDecl: []
#                 TypeDecl: None, [], None
#                   IdentifierType: ['char']
#             Typename: None, [], None
#               PtrDecl: []
#                 TypeDecl: None, [], None
#                   IdentifierType: ['char']
#           TypeDecl: PrintFunc, [], None
#             IdentifierType: ['void']

# %%
function_body = ast.ext[2].body
for_stmt = function_body.block_items[2]
for_stmt.show()
# Out:
# For:
#   Assignment: =
#     ID: i
#     Constant: int, 0
#   BinaryOp: <
#     ID: i
#     StructRef: ->
#       ID: hash
#       ID: table_size
#   UnaryOp: ++
#     ID: i
#   Compound:
#     Decl: temp, [], [], [], []
#       PtrDecl: []
#         TypeDecl: temp, [], None
#           IdentifierType: ['Node']
#       ArrayRef:
#         StructRef: ->
#           ID: hash
#           ID: heads
#         ID: i
#     While:
#       BinaryOp: !=
#         ID: temp
#         ID: NULL
#       Compound:
#         FuncCall:
#           ID: PrintFunc
#           ExprList:
#             StructRef: ->
#               StructRef: ->
#                 ID: temp
#                 ID: entry
#               ID: key
#             StructRef: ->
#               StructRef: ->
#                 ID: temp
#                 ID: entry
#               ID: value
#         Assignment: =
#           ID: temp
#           StructRef: ->
#             ID: temp
#             ID: next

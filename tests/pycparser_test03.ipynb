# %%
from c_dict import file_to_dict, string_to_dict

# %%
#ast_dict_original = file_to_dict("tests/test.c")
#print(ast_dict_original)

# %%
text = r"""static void init_array (int m, int n, DATA_TYPE *float_n, DATA_TYPE POLYBENCH_2D(data,N,M,n,m)) { int i, j; *float_n = (DATA_TYPE)N; for (i = 0; i < N; i++) for (j = 0; j < M; j++) data[i][j] = (DATA_TYPE)(i*j)/M + i; } static void print_array(int m, DATA_TYPE POLYBENCH_2D(corr,M,M,m,m)) { int i, j; POLYBENCH_DUMP_START; POLYBENCH_DUMP_BEGIN("corr"); for (i = 0; i < m; i++) for (j = 0; j < m; j++) { if ((i * m + j) % 20 == 0) fprintf (POLYBENCH_DUMP_TARGET, "\n"); fprintf (POLYBENCH_DUMP_TARGET, DATA_PRINTF_MODIFIER, corr[i][j]); } POLYBENCH_DUMP_END("corr"); POLYBENCH_DUMP_FINISH; } static void kernel_correlation(int m, int n, DATA_TYPE float_n, DATA_TYPE POLYBENCH_2D(data,N,M,n,m), DATA_TYPE POLYBENCH_2D(corr,M,M,m,m), DATA_TYPE POLYBENCH_1D(mean,M,m), DATA_TYPE POLYBENCH_1D(stddev,M,m)) { int i, j, k; DATA_TYPE eps = SCALAR_VAL(0.1); for (j = 0; j < _PB_M; j++) { mean[j] = SCALAR_VAL(0.0); for (i = 0; i < _PB_N; i++) mean[j] += data[i][j]; mean[j] /= float_n; } for (j = 0; j < _PB_M; j++) { stddev[j] = SCALAR_VAL(0.0); for (i = 0; i < _PB_N; i++) stddev[j] += (data[i][j] - mean[j]) * (data[i][j] - mean[j]); stddev[j] /= float_n; stddev[j] = SQRT_FUN(stddev[j]); stddev[j] = stddev[j] <= eps ? SCALAR_VAL(1.0) : stddev[j]; } for (i = 0; i < _PB_N; i++) for (j = 0; j < _PB_M; j++) { data[i][j] -= mean[j]; data[i][j] /= SQRT_FUN(float_n) * stddev[j]; } for (i = 0; i < _PB_M-1; i++) { corr[i][i] = SCALAR_VAL(1.0); for (j = i+1; j < _PB_M; j++) { corr[i][j] = SCALAR_VAL(0.0); for (k = 0; k < _PB_N; k++) corr[i][j] += (data[k][i] * data[k][j]); corr[j][i] = corr[i][j]; } } corr[_PB_M-1][_PB_M-1] = SCALAR_VAL(1.0); }"""
text = text.replace('DATA_TYPE', 'float')
text = text.replace('SCALAR_VAL', '')
text = text.replace('SQRT_FUN', 'sqrtf')
text = text.replace('EXP_FUN', 'expf')
text = text.replace('POW_FUN', 'powf')

# %%
ast_dict = string_to_dict(text)

# %%
print(ast_dict)
# Out:
# {'_nodetype': 'FileAST', 'coord': None, 'ext': [{'_nodetype': 'FuncDef', 'coord': '<none>:1:13', 'decl': {'_nodetype': 'Decl', 'name': 'init_array', 'quals': [], 'align': [], 'storage': ['static'], 'funcspec': [], 'coord': '<none>:1:13', 'type': {'_nodetype': 'FuncDecl', 'coord': '<none>:1:13', 'args': {'_nodetype': 'ParamList', 'coord': '<none>:1:29', 'params': [{'_nodetype': 'Decl', 'name': 'm', 'quals': [], 'align': [], 'storage': [], 'funcspec': [], 'coord': '<none>:1:29', 'type': {'_nodetype': 'TypeDecl', 'declname': 'm', 'quals': [], 'align': None, 'coord': '<none>:1:29', 'type': {'_nodetype': 'IdentifierType', 'names': ['int'], 'coord': '<none>:1:25'}}, 'bitsize': None, 'init': None}, {'_nodetype': 'Decl', 'name': 'n', 'quals': [], 'align': [], 'storage': [], 'funcspec': [], 'coord': '<none>:1:36', 'type': {'_nodetype': 'TypeDecl', 'declname': 'n', 'quals': [], 'align': None, 'coord': '<none>:1:36', 'type': {'_nodetype': 'IdentifierType', 'names': ['int'], 'coord': '<none>:1:3
# ...

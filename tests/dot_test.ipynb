# %%
from graphviz import Source
path = 'hello.c.019t.ssa.dot'
s = Source.from_file(path)
s.view()
# Out:
# 'hello.c.019t.ssa.dot.pdf'

# %%
s

# %%
str(s)
# Out:
# '<graphviz.files.Source object at 0x000001FCDD5E04C0>'

# %%
from graphviz import Source, Digraph, Graph

src = Source.from_file('hello.c.019t.ssa.dot')
lst = str(src).splitlines()

# %%
len(lst)
# Out:
# 1

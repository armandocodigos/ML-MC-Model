# %%
import loading as ld
polybench = ld.load_model('polybenchASTs.sav')

# %%
import plotting as pl
#g = pl.summarize_ast(polybench, 'covariance', multiple=False)
#g.view()
#g

# %%
pl.unique_ast(polybench, 'correlation')
# Out:
# 257
# ...
